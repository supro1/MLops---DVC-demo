# %%
import yaml
import json
import pandas as pd
with open("params.yml", "r") as s:
    y= yaml.load(s)
print(y)
# Out:
# {'base': {'project': 'winequality-project', 'random_state': 42, 'target_col': 'TARGET'}, 'data_source': {'s3_source': 'data_given/winequality.csv'}, 'load_data': {'raw_dataset_csv': 'data/raw/winequality.csv'}, 'split_data': {'train_path': 'data/processed/train_winequality.csv', 'test_path': 'data/processed/test_winequality.csv', 'test_size': 0.2}, 'estimators': {'ElasticNet': {'params': {'alpha': 0.9, 'l1_ratio': 0.4}}}, 'model_dir': 'saved_models', 'reports': {'params': 'report/params.json', 'scores': 'report/scores.json'}, 'webapp_model_dir': 'prediction_service/model/model.joblib'}
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
df = pd.DataFrame(y)

# %%
df
# Out:
#                                 base                 data_source  \
# project          winequality-project                         NaN
# random_state                      42                         NaN
# target_col                    TARGET                         NaN
# s3_source                        NaN  data_given/winequality.csv
# raw_dataset_csv                  NaN                         NaN
# train_path                       NaN                         NaN
# test_path                        NaN                         NaN
# test_size                        NaN                         NaN
# ElasticNet                       NaN                         NaN
# params                           NaN                         NaN
# scores                           NaN                         NaN
#
#                                 load_data  \
# project                               NaN
# random_state                          NaN
# target_col                            NaN
# ...
